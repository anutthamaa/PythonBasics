# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# helps in creating the graphs in the notebook otherwise they will pop up

# %%
data = pd.read_csv('student.csv')
display (data.head())
# Out:
#        ID school sex  age address famsize Pstatus  Medu  Fedu     Mjob  ...  \
# 0  SD0001     GP   F   18       U     GT3       A     4     4  at_home  ...
# 1  SD0002     GP   F   17       U     GT3       T     1     1  at_home  ...
# 2  SD0003     GP   F   15       U     LE3       T     1     1  at_home  ...
# 3  SD0004     GP   F   15       U     GT3       T     4     2   health  ...
# 4  SD0005     GP   F   16       U     GT3       T     3     3    other  ...
#
#   internet romantic famrel  freetime  goout  Dalc Walc health absences Grade
# 0       no       no    NaN         3      4     1    1      3      NaN     1
# 1      yes       no    NaN         3      3     1    1      3      NaN     1
# 2      yes       no    NaN         3      2     2    3      3     10.0     2
# 3      yes      yes    3.0         2      2     1    1      5      2.0     3
# 4       no       no    4.0         3      2     1    2      5      4.0     2
#
# [5 rows x 32 columns]

# %%
data.shape
# Out:
# (395, 32)

# %%
data.info()

# Null Count - missing value in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          395 non-null    object
#  1   school      395 non-null    object
#  2   sex         395 non-null    object
#  3   age         395 non-null    int64
#  4   address     395 non-null    object
#  5   famsize     395 non-null    object
#  6   Pstatus     395 non-null    object
#  7   Medu        395 non-null    int64
#  8   Fedu        395 non-null    int64
#  9   Mjob        395 non-null    object
#  10  Fjob        395 non-null    object
#  11  reason      395 non-null    object
#  12  guardian    395 non-null    object
#  13  traveltime  395 non-null    int64
#  14  studytime   395 non-null    int64
#  15  failures    395 non-null    int64
#  16  schoolsup   395 non-null    object
#  17  famsup      395 non-null    object
#  18  paid        395 non-null    object
#  19  activities  311 non-null    object
#  20  nursery     395 non-null    object
#  21  higher      395 non-null    object
#  22  internet    395 non-null    object
#  23  romantic    395 non-null    object
#  24  famrel      278 non-null    float64
#  25  freetime    395 non-null    int64
#  26  goout       395 non-null    int64
#  27  Dalc        395 non-null    int64
#  28  Walc        395 non-null    int64
#  29  health      395 non-null    int64
#  30  absences    337 non-null    float64
#  31  Grade       395 non-null    int64
# dtypes: float64(2), int64(12), object(18)
# memory usage: 98.9+ KB

# %%
data.columns
# Out:
# Index(['ID', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'Grade'],
#       dtype='object')

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# Attribute Information ::
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1.	school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2.	sex - student's sex (binary: 'F' - female or 'M' - male)
# 3.	age - student's age (numeric: from 15 to 22)
# 4.	address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5.	famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6.	Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7.	Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
# 8.	Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# 9.	Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10.	Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11.	reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12.	guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13.	traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14.	studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15.	failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16.	schoolsup - extra educational support (binary: yes or no)
# 17.	famsup - family educational support (binary: yes or no)
# 18.	paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19.	activities - extra-curricular activities (binary: yes or no)
# 20.	nursery - attended nursery school (binary: yes or no)
# 21.	higher - wants to take higher education (binary: yes or no)
# 22.	internet - Internet access at home (binary: yes or no)
# 23.	romantic - with a romantic relationship (binary: yes or no)
# 24.	famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25.	freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26.	goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27.	Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28.	Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29.	health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30.	absences - number of school absences (numeric: from 0 to 93)

# %% [markdown]
# ## isnull()
# - The isnull() function is used to detect missing values for an array-like object.
#
# - This function takes a scalar or array-like object and indicates whether values are missing (NaN in numeric arrays)

# %%
data.isnull()

# it will only check for NAN and not BLANK VALUES
# TRUE = NAN = Missing Value
# Out:
#         ID  school    sex    age  address  famsize  Pstatus   Medu   Fedu  \
# 0    False   False  False  False    False    False    False  False  False
# 1    False   False  False  False    False    False    False  False  False
# 2    False   False  False  False    False    False    False  False  False
# 3    False   False  False  False    False    False    False  False  False
# 4    False   False  False  False    False    False    False  False  False
# ..     ...     ...    ...    ...      ...      ...      ...    ...    ...
# 390  False   False  False  False    False    False    False  False  False
# 391  False   False  False  False    False    False    False  False  False
# 392  False   False  False  False    False    False    False  False  False
# 393  False   False  False  False    False    False    False  False  False
# 394  False   False  False  False    False    False    False  False  False
#
#       Mjob  ...  internet  romantic  famrel  freetime  goout   Dalc   Walc  \
# 0    False  ...     False     False    True     False  False  False  False
# 1    False  ...     False     False    True     False  False  False  False
# 2    False  ...     False     False    True     False  False  False  False
# 3    False  ...     False     False   False     False  False  False  False
# 4    False  ...     False     False   False     False  False  False  False
# ..     ...  ...       ...       ...     ...       ...    ...    ...    ...
# 390  False  ...     False     False   False     False  False  False  False
# 391  False  ...     False     False    True     False  False  False  False
# 392  False  ...     False     False   False     False  False  False  False
# 393  False  ...     False     False    True     False  False  False  False
# 394  False  ...     False     False   False     False  False  False  False
#
#      health  absences  Grade
# 0     False      True  False
# 1     False      True  False
# 2     False     False  False
# 3     False     False  False
# 4     False     False  False
# ..      ...       ...    ...
# 390   False     False  False
# 391   False     False  False
# 392   False     False  False
# 393   False     False  False
# 394   False     False  False
#
# [395 rows x 32 columns]

# %%
data.isnull().sum() # col wise sum ===  T = 1 and F = 0
# Out:
# ID              0
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            0
# Fjob            0
# reason          0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# schoolsup       0
# famsup          0
# paid            0
# activities     84
# nursery         0
# higher          0
# internet        0
# romantic        0
# famrel        117
# freetime        0
# goout           0
# Dalc            0
# Walc            0
# health          0
# absences       58
# Grade           0
# dtype: int64

# %% [markdown]
# ## Deletion

# %%
data_del = data.dropna(how = "any") # any row that has a missing value drop it

# %%
print ('Before: ', data.shape, 'After: ', data_del.shape)
# Out:
# Before:  (395, 32) After:  (182, 32)

# %%
395 - 182
# Out:
# 213

# %%
round(213/395, 2)
# Out:
# 0.54

# %% [markdown]
# **We will end up deleting 54% of data.**
#
# **We will lose 54% of the data, this will hamper the analysis, since we require large amount of data for Predictive Analysis.**

# %% [markdown]
# ## Imputation of Continuous Values

# %%
import seaborn as sns
sns.displot(data.absences, kde = True);

# %% [markdown]
# #### Since, the data is positively skewed, we will use the median to impute the missing values

# %%
data.absences.median()
# Out:
# 4.0

# %%
data.absences.head()
# Out:
# 0     NaN
# 1     NaN
# 2    10.0
# 3     2.0
# 4     4.0
# Name: absences, dtype: float64

# %% [markdown]
# - **The fillna() function is used to fill NA/NaN values using the specified method.**

# %%
data.absences.fillna(data.absences.median(), inplace = True)
data.absences.head()
# Out:
# 0     4.0
# 1     4.0
# 2    10.0
# 3     2.0
# 4     4.0
# Name: absences, dtype: float64

# %%
data.absences.isnull().sum() # total number of missing value in the absences column
# Out:
# 0

# %% [markdown]
# ## Imputation for Categorical Variables

# %%
data.activities.head(10)
# Out:
# 0     no
# 1     no
# 2     no
# 3    yes
# 4    NaN
# 5    yes
# 6     no
# 7    NaN
# 8     no
# 9    NaN
# Name: activities, dtype: object

# %%
data.activities.mode() # multiple modes in a dataset
# Out:
# 0    yes
# dtype: object

# %%
data.activities.mode()[0] # 0 is the index here
# Out:
# 'yes'

# %%
data.activities.fillna(data.activities.mode()[0], inplace=True)
data.activities.head(10)
# Out:
# 0     no
# 1     no
# 2     no
# 3    yes
# 4    yes
# 5    yes
# 6     no
# 7    yes
# 8     no
# 9    yes
# Name: activities, dtype: object

# %% [markdown]
# # Q. Famrel - impute the missing values

# %% [markdown]
# # Outliers Detection

# %%
sns.boxplot(x = data.absences).set(title = "Boxplot of Absences Column");
# x - Horizontal Boxplot

# %%
sns.boxplot(y = data.absences).set(title = "Boxplot of Absences Column");
# x - Vertical Boxplot

# %%
min_value = data['absences'].min()
Q1 = data['absences'].quantile(0.25)
median_value = data['absences'].median()
Q3 = data['absences'].quantile(0.75)
max_value = data['absences'].max()


print ("min_value    :", min_value)
print ("Q1           :", Q1)
print ("median_value :", median_value)
print ("Q3           :", Q3)
print ("max_value    :", max_value)
# Out:
# min_value    : 0.0
# Q1           : 0.0
# median_value : 4.0
# Q3           : 6.5
# max_value    : 75.0

# %% [markdown]
# **Not Outliers = (Q1 - 1.5 * IQR) <= data <= (Q3 + 1.5 * IQR)**
# - Q1 - 1st Quartile
# - Q3 - 3rd Quartile
# - Q3-Q1 - IQR

# %%
IQR = Q3 - Q1
IQR
# Out:
# 6.5

# %%
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# data points less than lower_limit are outliers
# data points greater than upper limit are outliers

print (lower_limit)
print (upper_limit)
# Out:
# -9.75
# 16.25

# %% [markdown]
# ## Deleting Outliers

# %%
data.loc[data.absences <= lower_limit] # outliers
# Out:
# Empty DataFrame
# Columns: [ID, school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, Grade]
# Index: []
#
# [0 rows x 32 columns]

# %%
data.loc[data.absences >= upper_limit] # outliers
# Out:
#          ID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 74   SD0075     GP   F   16       U     GT3       T     3     3     other
# 89   SD0090     GP   M   16       U     LE3       A     4     4   teacher
# 103  SD0104     GP   F   15       U     GT3       T     3     2  services
# 118  SD0119     GP   M   17       R     GT3       T     1     3     other
# 123  SD0124     GP   M   16       U     GT3       T     4     4    health
# 183  SD0184     GP   F   17       U     LE3       T     3     3     other
# 198  SD0199     GP   F   17       U     GT3       T     4     4  services
# 203  SD0204     GP   F   17       R     GT3       T     2     2     other
# 205  SD0206     GP   F   17       U     GT3       T     3     4   at_home
# 216  SD0217     GP   F   17       U     GT3       T     4     3     other
# 234  SD0235     GP   M   16       U     LE3       T     1     1     other
# 237  SD0238     GP   F   16       U     GT3       T     2     1     other
# 260  SD0261     GP   F   18       U     GT3       T     4     3  services
# 276  SD0277     GP   F   18       R     GT3       A     3     2     other
# 277  SD0278     GP   M   18       U     GT3       T     4     4   teacher
# 280  SD0281     GP   M   17       U     LE3       A     4     1  services
# 281  SD0282     GP   M   17       U     LE3       A     3     2   teacher
# 304  SD0305     GP   M   19       U     GT3       T     3     3     other
# 307  SD0308     GP   M   19       U     GT3       T     4     4   teacher
# 309  SD0310     GP   F   19       U     LE3       T     1     1   at_home
# 311  SD0312     GP   F   19       U     GT3       T     2     1   at_home
# 313  SD0314     GP   F   19       U     LE3       T     3     2  services
# 315  SD0316     GP   F   19       R     GT3       T     2     3     other
# 320  SD0321     GP   F   17       U     GT3       A     4     3  services
# 379  SD0380     MS   F   17       R     GT3       T     3     1   at_home
#
#      ... internet romantic famrel  freetime  goout  Dalc Walc health absences  \
# 74   ...      yes       no    4.0         3      3     2    4      5     54.0
# 89   ...       no       no    4.0         1      3     3    5      5     18.0
# 103  ...      yes       no    4.0         3      5     1    1      2     26.0
# 118  ...      yes       no    NaN         2      4     1    4      5     20.0
# 123  ...      yes       no    3.0         4      4     1    4      5     18.0
# 183  ...      yes      yes    5.0         3      3     2    3      1     56.0
# 198  ...      yes       no    4.0         2      4     2    3      2     24.0
# 203  ...      yes       no    NaN         3      2     1    2      3     18.0
# 205  ...      yes      yes    4.0         4      3     3    4      5     28.0
# 216  ...      yes      yes    NaN         4      5     2    4      1     22.0
# 234  ...      yes       no    3.0         4      2     1    1      5     18.0
# 237  ...      yes      yes    4.0         5      2     1    1      5     20.0
# 260  ...      yes      yes    3.0         1      2     1    3      2     21.0
# 276  ...      yes      yes    4.0         1      1     1    1      5     75.0
# 277  ...      yes       no    3.0         2      4     1    4      3     22.0
# 280  ...      yes      yes    NaN         5      4     2    4      5     30.0
# 281  ...      yes       no    4.0         4      4     3    4      3     19.0
# 304  ...      yes      yes    4.0         4      4     1    1      3     20.0
# 307  ...      yes      yes    4.0         3      4     1    1      4     38.0
# 309  ...      yes       no    4.0         4      3     1    3      3     18.0
# 311  ...      yes      yes    3.0         4      1     1    1      2     20.0
# 313  ...      yes      yes    4.0         2      2     1    2      1     22.0
# 315  ...      yes      yes    4.0         1      2     1    1      3     40.0
# 320  ...      yes      yes    5.0         2      2     1    2      5     23.0
# 379  ...      yes       no    NaN         5      4     2    3      1     17.0
#
#     Grade
# 74      3
# 89      1
# 103     1
# 118     2
# 123     3
# 183     2
# 198     3
# 203     1
# 205     2
# 216     1
# 234     2
# 237     3
# 260     3
# 276     2
# 277     2
# 280     2
# 281     2
# 304     3
# 307     2
# 309     2
# 311     3
# 313     3
# 315     3
# 320     3
# 379     2
#
# [25 rows x 32 columns]

# %% [markdown]
# 25 rows will be deleted

# %%
data.shape
# Out:
# (395, 32)

# %%
data.loc[data.absences >= upper_limit].index
data.drop(data.loc[data.absences >= upper_limit].index, axis = 0) # not update the data
# Out:
#          ID school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0    SD0001     GP   F   18       U     GT3       A     4     4   at_home
# 1    SD0002     GP   F   17       U     GT3       T     1     1   at_home
# 2    SD0003     GP   F   15       U     LE3       T     1     1   at_home
# 3    SD0004     GP   F   15       U     GT3       T     4     2    health
# 4    SD0005     GP   F   16       U     GT3       T     3     3     other
# ..      ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390  SD0391     MS   M   20       U     LE3       A     2     2  services
# 391  SD0392     MS   M   17       U     LE3       T     3     1  services
# 392  SD0393     MS   M   21       R     GT3       T     1     1     other
# 393  SD0394     MS   M   18       R     LE3       T     3     2  services
# 394  SD0395     MS   M   19       U     LE3       T     1     1     other
#
#      ... internet romantic famrel  freetime  goout  Dalc Walc health absences  \
# 0    ...       no       no    NaN         3      4     1    1      3      4.0
# 1    ...      yes       no    NaN         3      3     1    1      3      4.0
# 2    ...      yes       no    NaN         3      2     2    3      3     10.0
# 3    ...      yes      yes    3.0         2      2     1    1      5      2.0
# 4    ...       no       no    4.0         3      2     1    2      5      4.0
# ..   ...      ...      ...    ...       ...    ...   ...  ...    ...      ...
# 390  ...       no       no    5.0         5      4     4    5      4     11.0
# 391  ...      yes       no    NaN         4      5     3    4      2      3.0
# 392  ...       no       no    5.0         5      3     3    3      3      3.0
# 393  ...      yes       no    NaN         4      1     3    4      5      0.0
# 394  ...      yes       no    3.0         2      3     3    3      5      5.0
#
#     Grade
# 0       1
# 1       1
# 2       2
# 3       3
# 4       2
# ..    ...
# 390     2
# 391     3
# 392     2
# 393     2
# 394     2
#
# [370 rows x 32 columns]

# %%
data = data.loc[data.absences <= upper_limit] # deleted the outliers
data.shape
