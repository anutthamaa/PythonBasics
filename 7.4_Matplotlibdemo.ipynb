# %%
#numpy library to generate random numbers
import numpy as np
#import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

# %%
#generate random numbers(value=10)
randomNumber=np.random.rand(10)
randomNumber
# Out:
# array([0.33529961, 0.42723667, 0.63057404, 0.15140931, 0.74398349,
#        0.52622192, 0.40969085, 0.92469119, 0.68430151, 0.80318267])

# %%
#select the style of the plot
style.use('ggplot')
#plot the random number
plt.plot(randomNumber,'g',label='line_one',linewidth=2)
#x axis is no of random numbers
plt.xlabel('Range')
#y axis is actual random numbers
plt.ylabel('Numbers')
#title of the plot
plt.title('First Plot')
#plt.legend()
#plt.show()
# Out:
# Text(0.5, 1.0, 'First Plot')

# %%
#data from ohio states, leading causes of deaths in year 2012
cause='Chronic diseases','Unintentional injuries','Alzhiemers','Influenza and Pneumonia','Sepsis','Others'
percentile=[62,5,4,2,1,26]

# %%
#set the pie chart plot properties
#set figure size
plt.figure(figsize=(10,10))
#explode the largest pie in the dataset
explode=(0.05,0,0,0,0,0)
#set pie chart properties
plt.pie(percentile,labels=cause,explode=explode,autopct='%1.1f%%',startangle=70)
#set axis equal to draw pie as circle
plt.axis('equal')
#set title of pie chart
plt.title('Ohio state 2012-Leading causes of death')
#show the pie chart
plt.show()
